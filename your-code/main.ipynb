# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
pip install seaborn
# Out:
# ...
#      |████████████████████████████████| 292 kB 3.2 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit=pd.read_csv("/Users/Juliana/Desktop/Ironhack/Week_2/lab-matplotlib-seaborn/data/Fitbit2.csv")
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fitbitt=fitbit[["Months_encoded", "Work_or_Weekend","Steps"]]
fitbitt
# Out:
#      Months_encoded  Work_or_Weekend  Steps
# 0                 5                1    905
# 1                 5                0  18925
# 2                 5                0  14228
# 3                 5                1   6756
# 4                 5                1    502
# ..              ...              ...    ...
# 362               5                1  18588
# 363               5                1  16382
# 364               5                1  21913
# 365               5                1  19023
# 366               5                0   9526
#
# [367 rows x 3 columns]

# %%
# AVERAGE STEPS BY MONTH_ENCODED
fitbit.groupby(["Months_encoded"])["Steps"].mean().plot(kind='bar')
f.savefig(f'output/{columns}.png')

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
fitbit.groupby(["Work_or_Weekend"])["Steps"].mean().plot(kind='bar')
f.savefig(f'output/{columns}.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fitbit2=fitbit[["Minutes Lightly Active", "Minutes Very Active","Minutes Sedentary","Steps"]]
fitbit2
# Out:
#      Minutes Lightly Active  Minutes Very Active  Minutes Sedentary  Steps
# 0                        46                    0              1.355    905
# 1                       316                   60            611.000  18925
# 2                       226                   77            602.000  14228
# 3                       190                    4            749.000   6756
# 4                       171                    0            876.000    502
# ..                      ...                  ...                ...    ...
# 362                     275                   79            599.000  18588
# 363                     333                   55            684.000  16382
# 364                     287                   90            701.000  21913
# 365                     298                   85            575.000  19023
# 366                     370                   10            564.000   9526
#
# [367 rows x 4 columns]

# %%
# your code here
figures = []

for columns in fitbit2:
    if columns != 'Steps':
        f = plt.figure(figsize=(12,4))
        figures += [f]  # This appends a figure f to the list of figures
        sns.scatterplot(x=columns, y="Steps", data=fitbit)
        f.savefig(f'output/{columns}.png')
# !ls
# Out:
# main.ipynb output

# %%
# !open .

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic=pd.read_csv("/Users/Juliana/Desktop/Ironhack/Week_2/lab-matplotlib-seaborn/data/titanic.csv")
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
# your code here
titanic.shape
# Out:
# (1309, 12)

# %%
titanic.describe
# Out:
# <bound method NDFrame.describe of       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %%
titanic.describe(percentiles=[0.10,0.50,0.95])
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1309.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.879186     0.498854
# std     378.020061    0.486592     0.837836    13.448335     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 10%     131.800000    0.000000     1.000000    15.800000     0.000000
# 50%     655.000000    0.000000     3.000000    28.500000     0.000000
# 95%    1243.600000    1.000000     3.000000    55.000000     2.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1309.000000
# mean      0.385027    33.281086
# std       0.865560    51.741500
# min       0.000000     0.000000
# 10%       0.000000     7.570000
# 50%       0.000000    14.454200
# 95%       2.000000   133.650000
# max       9.000000   512.329200

# %%
titanic.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name Gender   Age  SibSp  \
# 0            1       0.0       3  Braund, Mr. Owen Harris   male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25    U0        S

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include=["object"])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include=["int64","float64"])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
sns.set_style("darkgrid")
sns.scatterplot(x="Fare", y="Age", data=titanic)
plt.figure(figsize=(12,6))

# %%
plt.style.use('classic')
#titanic[["Fare","Age"]].plot(kind='scatter')
plt.scatter(titanic.Fare, titanic.Age)
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
sns.set_style("darkgrid")
sns.histplot(x="Age", data=titanic)
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, axs = plt.subplots(nrows=1, ncols=3)

sns.histplot(data=titanic, x="Age", bins=10,ax=axs[0])
sns.histplot(data=titanic, x="Age", bins=20,ax=axs[1])
sns.histplot(data=titanic, x="Age", bins=50,ax=axs[2])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
changes the clarity of the distribution
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.set_style("darkgrid")
sns.histplot(x="Age", data=titanic,kde=True)
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
titanic["Gender"].value_counts().plot(kind="bar", color="salmon", figsize=(12,6))
plt.xticks(rotation=0)
# Out:
# <AxesSubplot:>

# %%
titanic["Gender"].value_counts().plot(kind="pie",figsize=(12,6))
plt.xticks(rotation=0)
#terrible
# Out:
# (array([], dtype=float64), [])

# %%
# Method 2 - seaborn
sns.set_style("darkgrid")
sns.countplot(x="Gender", data=titanic)
plt.figure(figsize=(12,6))

# %%
datos = titanic["Gender"].value_counts()
datos.plot.pie(autopct="%.1f%%")
#omg😒😒😒😒
# Out:
# <AxesSubplot:ylabel='Gender'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.set_style("darkgrid")
sns.countplot(x="Pclass", data=titanic)
plt.figure(figsize=(12,6))

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
violin = sns.violinplot(x=titanic.Age)
violin.axvline(x=titanic.Age.median(), c="red", label="median")
plt.legend()

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
That most people were between 20 and 30
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.set_style("darkgrid")
sns.histplot(x="Age", data=titanic,kde=True)
plt.figure(figsize=(12,6))

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
that distribution was  skewed to the right, having younger passengers (maybe not that young for the time)

"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.style.use('classic')
#titanic[["Fare","Age"]].plot(kind='scatter')
plt.scatter(titanic.Fare, titanic.Age)
plt.figure(figsize=(12,6))

# %%
# Method 2 - seaborn
sns.set_style("darkgrid")
sns.scatterplot(x="Fare", y="Age", data=titanic)
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
corr = titanic.corr()
corr

mask = np.triu(np.ones_like(corr, dtype=bool)) 
color_map = sns.diverging_palette(0, 10, as_cmap=True)
sns.heatmap(corr,  
            mask = mask,
            cmap=color_map,
            square=True, 
            linewidth=0.5, 
            vmax=1,
            cbar_kws={"shrink": .5}
);

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Class - Fare, Class - Age, Class - Survived
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(x="Pclass", y="Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.catplot(data=titanic, x="Age", y="Gender", jitter=True)
