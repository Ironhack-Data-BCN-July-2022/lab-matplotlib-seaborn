# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# Your Code Here

# %%
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'

# %%
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
pwd
# Out:
# 'C:\\Users\\Edgard_Cuadra\\OneDrive\\Desktop\\Ironhack\\Laboratorios\\lab-matplotlib-seaborn\\your-code'

# %%
cd ..
# Out:
# C:\Users\Edgard_Cuadra\OneDrive\Desktop\Ironhack\Laboratorios\lab-matplotlib-seaborn

# %%
cd data
# Out:
# C:\Users\Edgard_Cuadra\OneDrive\Desktop\Ironhack\Laboratorios\lab-matplotlib-seaborn\data

# %%
# your code here
fitbit = pd.read_csv("./Fitbit2.csv")

# %%
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here

# %%
week = fitbit[["Steps","Work_or_Weekend"]]
week.head()
# Out:
#    Steps  Work_or_Weekend
# 0    905                1
# 1  18925                0
# 2  14228                0
# 3   6756                1
# 4    502                1

# %%
avg_week = week.groupby(['Work_or_Weekend']).mean()
avg_week.head()
# Out:
#                         Steps
# Work_or_Weekend
# 0                10064.238095
# 1                10144.572519

# %%
avg_week["Steps"].plot(kind="bar",color= "forestgreen")
# Out:
# <AxesSubplot:xlabel='Work_or_Weekend'>

# %%
month = fitbit[["Steps","Months_encoded"]]
month.head()
# Out:
#    Steps  Months_encoded
# 0    905               5
# 1  18925               5
# 2  14228               5
# 3   6756               5
# 4    502               5

# %%
avg_steps = month.groupby(['Months_encoded']).mean()
avg_steps.head()
# Out:
#                        Steps
# Months_encoded
# 1                9892.064516
# 2                8922.866667
# 3               10312.935484
# 4               13079.033333
# 5               10620.096774

# %%
avg_steps["Steps"].plot(kind="bar",color= "forestgreen")
# Out:
# <AxesSubplot:xlabel='Months_encoded'>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
newfitbit = fitbit[["Steps","Minutes Lightly Active","Minutes Very Active","Minutes Sedentary"]]
newfitbit.head()
# Out:
#    Steps  Minutes Lightly Active  Minutes Very Active  Minutes Sedentary
# 0    905                      46                    0              1.355
# 1  18925                     316                   60            611.000
# 2  14228                     226                   77            602.000
# 3   6756                     190                    4            749.000
# 4    502                     171                    0            876.000

# %%
sns.scatterplot(x="Minutes Lightly Active", y="Steps", data=newfitbit);

# %%
for column in newfitbit: # For Loop for every column in the df "newfitbit"
    if column != "Steps": # checks for all columns that are not "Steps"
        f = plt.figure(figsize=(12,4)) # this will store the image in a variable  
        sns.scatterplot(x=column, y="Steps", data=newfitbit) #creates the scatterplots
        f.savefig(f'{column}.png') # this will save the image as a file can be(png,jpg,jpeg)

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv("./titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes()
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic._get_numeric_data()
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include=object)
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
sns.histplot(x=titanic.Age, bins=10);

# %%
sns.histplot(x=titanic.Age, bins=20);

# %%
sns.histplot(x=titanic.Age, bins=50);

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
the histogram remain skewed to the left
but the greater the number of bins the 
more precise it becomes
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
sns.countplot(x=titanic.Gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
gender = titanic[["Gender","PassengerId"]]
gender.head()
# Out:
#    Gender  PassengerId
# 0    male            1
# 1  female            2
# 2  female            3
# 3  female            4
# 4    male            5

# %%
gender["Gender"].value_counts().plot(kind="bar",color= "forestgreen")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x=titanic.Pclass)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(x="Age", data=titanic);

# %%
"""
the great mayority of people in titanic 
had between 22 and 38 years of age.
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
the average age of pasager is 28 years
the q3 is between 28 and 37
the q1 is between 22 and 28
the max is 60
the min is 0 
and there are several outliers
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.histplot(x=titanic.Age,kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
it shows that the great mayority of passager where
distributed between 20 and 40 years of age
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter("Age","Fare",data=titanic)

# %%
# Method 2 - seaborn
sns.scatterplot(x="Age", y="Fare", data=titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr = titanic.corr()
corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %%
mask = np.triu(np.ones_like(corr, dtype=bool)) 
color_map = sns.diverging_palette(0, 10, as_cmap=True)
sns.heatmap(corr,  
            mask = mask,
            cmap=color_map,
            square=True, 
            linewidth=0.5, 
            vmax=1,
            cbar_kws={"shrink": .5}
);

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
there is great corrolation between the pclass and fare, 
but more interestingly there is a high corrolation between
pclass and survival as well as age
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(x="Pclass", y="Age", data=titanic);

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.boxplot(x="Gender", y="Age", data=titanic);
