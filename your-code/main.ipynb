# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,4.)})
sns.set_style("whitegrid")

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit=pd.read_csv('../data/Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
fitbit.groupby(["Months_encoded"])["Steps"].mean().plot(kind='bar')
fig1 = plt.figure(figsize=(12,4))
# !mkdir ../figures
fig1.savefig('/Users/nicostan/Downloads/Ironhack/labs/lab-matplotlib-seaborn/figures/Months_encoded.png')
# Out:
# mkdir: ../figures: File exists

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
fitbit.groupby(["Work_or_Weekend"])["Steps"].mean().plot(kind='bar', color='forestgreen')
fig2 = plt.figure(figsize=(12,4))
fig2.savefig('/Users/nicostan/Downloads/Ironhack/labs/lab-matplotlib-seaborn/figures/Work_or_Weekend.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
active=['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']
for i in active:
    plt.figure()
    plt.scatter(fitbit[i], fitbit['Steps'])
plt.show()

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic=pd.read_csv('../data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(np.number).head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes('object').head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("classic")

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic.Age.plot.hist(bins=30, color="#fd7e14",rwidth=0.9);

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, axes = plt.subplots(1, 3, sharey=True)
fig.suptitle('Age distribution by number of bins')

titanic.Age.plot.hist(ax=axes[0], bins=10, color="#fd7e14",rwidth=0.9);
axes[0].set_title('10 bins')

titanic.Age.plot.hist(ax=axes[1], bins=20, color="#fd7e14",rwidth=0.9);
axes[1].set_title('20 bins')

titanic.Age.plot.hist(ax=axes[2], bins=50, color="#fd7e14",rwidth=0.9);
axes[2].set_title('50 bins')
# Out:
# Text(0.5, 1.0, '50 bins')

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The larger the bin sizes, the fewer bins there will be to cover the whole range of data.
The selected number of bins has to be close enough to follow the distribution trend of the data
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(titanic["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
titanic["Gender"].value_counts().plot(kind="bar", color="green", figsize=(12,6), title="Passengers by gender")
plt.xticks(rotation=0);

# %%
# Method 2 - seaborn
sns.histplot(x=titanic.Gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x=titanic.Pclass)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
#Boxplot
sns.boxplot(x="Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
"""
A boxplot serves to  visualize the statistics of the feature `Age`. We can se the minum and maximum values,
the median and the values within the IQR as well as other metrics
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
We can observe various outliers on the right end, over 60, and the majority of the sample ranges from 22/23 to 36/37. 
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.histplot(x="Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
It allows to see the which groups of ages are the most numerous and better visualize where the bulk of the data
is located.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass                          Name  Gender  \
# 257          258       1.0       1          Cherry, Miss. Gladys  female
# 392          393       0.0       3  Gustafsson, Mr. Johan Birger    male
# 852          853       0.0       3       Boulos, Miss. Nourelain  female
# 282          283       0.0       3     de Pelsmaeker, Mr. Alfons    male
# 891          892       NaN       3              Kelly, Mr. James    male
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 257  30.0      0      0   110152  86.5000   B77        S
# 392  28.0      2      0  3101277   7.9250    U0        S
# 852   9.0      1      1     2678  15.2458    U0        C
# 282  16.0      0      0   345778   9.5000    U0        S
# 891  34.5      0      0   330911   7.8292    U0        Q

# %%
# Method 2 - seaborn
sns.lineplot(x="Fare", y="Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Age'>

# %%
sns.scatterplot(x="Age", y="Fare", data=titanic);

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr = titanic.corr()
corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %%
mask = np.triu(np.ones_like(corr, dtype=bool)) 
color_map = sns.diverging_palette(0, 10, as_cmap=True)
sns.heatmap(corr,  
            mask = mask,
            cmap=color_map,
            square=True, 
            linewidth=0.5, 
            vmax=1,
            cbar_kws={"shrink": .5}
);

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Pclass/Fare and Pclass/Age
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.catplot(data=titanic, x="Pclass", y="Age", jitter=True)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.catplot(data=titanic, x="Gender", y="Age", jitter=True)
