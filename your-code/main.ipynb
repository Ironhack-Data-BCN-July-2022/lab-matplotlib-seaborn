# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv(r'C:\Users\lenovo\Desktop\viz-1\lab-matplotlib-seaborn\data\fitbit2.csv')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fitbit1 = fitbit.sample(5)
print(fitbit.columns)
#a baix cada mes i a dalt el numero de passos.
fitbit1
# Out:
# Index(['Date', 'Calorie burned', 'Steps', 'Distance', 'Floors',
#        'Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Fairly Active',
#        'Minutes Very Active', 'Activity Calories', 'MinutesOfSleep',
#        'MinutesOfBeingAwake', 'NumberOfAwakings', 'LengthOfRestInMinutes',
#        'Distance_miles', 'Days', 'Days_encoded', 'Work_or_Weekend',
#        'Hours Sleep', 'Sleep efficiency', 'Yesterday_sleep',
#        'Yesterday_sleep_efficiency', 'Months', 'Months_encoded'],
#       dtype='object')
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 120  2015-09-05            2885  10681      7.94       1              656.0
# 53   2015-06-30            2945  12445      9.25      11              635.0
# 76   2015-07-23            2984    909      6.75      17              719.0
# 5    2015-05-13             276    779      5.79      15              726.0
# 294  2016-02-25            2816   7941      5.90       9              878.0
#
# ...

# %%
sns.set_style("darkgrid")

# %%
fitbit_mean_steps = fitbit.groupby("Months_encoded")["Steps"].median()
figure1 = fitbit_mean_steps.plot(kind="bar", figsize=(8, 6))
figure1.figure.savefig(r"C:\Users\lenovo\Desktop\viz-1\Figures", dpi=800)

# %%
fitbit_week_steps = fitbit.groupby("Work_or_Weekend")["Steps"].median()
figure2 = fitbit_week_steps.plot(kind="bar", figsize=(8,6))
figure2.figure.savefig(r"C:\Users\lenovo\Desktop\viz-1\Figures", dpi=800)

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
sns.scatterplot(x="Minutes Lightly Active", y="Steps", data=fitbit)
# Out:
# <AxesSubplot:xlabel='Minutes Lightly Active', ylabel='Steps'>

# %%
sns.scatterplot(x="Minutes Very Active", y="Steps", data=fitbit)
# Out:
# <AxesSubplot:xlabel='Minutes Very Active', ylabel='Steps'>

# %%
sns.scatterplot(x="Minutes Sedentary", y="Steps", data=fitbit)
# Out:
# <AxesSubplot:xlabel='Minutes Sedentary', ylabel='Steps'>

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv(r"C:\Users\lenovo\Desktop\viz-1\lab-matplotlib-seaborn\data\titanic.csv")
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = titanic.select_dtypes(include=numerics)
newdf
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
not_numeric = titanic.select_dtypes(exclude=numerics)
not_numeric
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.figure(figsize=(12, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic.Age.plot.hist(by=None, bins=10,)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
titanic.Age.plot.hist(by=None, bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic.Age.plot.hist(by=None, bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic.Age.plot.hist(by=None, bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
higher bins = more readibility, but less precision.
"""
# Out:
# '\nhigher bins = more readibility, but less precision.\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(x= "Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
titanic['Gender'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# Method 2 - seaborn
sns.countplot(x= "Gender", data = titanic)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x= "Pclass", data = titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
stats = titanic["Age"].describe().to_string()
stats
# Out:
# 'count    1309.000000\nmean       29.879186\nstd        13.448335\nmin         0.170000\n25%        22.000000\n50%        28.500000\n75%        37.000000\nmax        80.000000'

# %%
sns.histplot(data = titanic["Age"], stat = 'probability')
plt.figtext(0.1,0.5, titanic["Age"].describe().to_string())
plt.show()

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
it gives me general information about the age variable.
"""
# Out:
# '\nit gives me general information about the age variable.\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
graf = sns.histplot(x=titanic.Age, kde=True)
plt.figtext(0.1,0.5, titanic["Age"].describe().to_string())
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
the distribution of the variable
"""
# Out:
# '\nthe distribution of the variable\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(titanic["Fare"], titanic["Age"])

# %%
# Method 2 - seaborn
plt.figure(figsize=(14,8))
sns.regplot(x=titanic["Fare"], y=titanic["Age"])
plt.title('Fare vs. Age')
# Out:
# Text(0.5, 1.0, 'Fare vs. Age')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr = titanic.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": 1})
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
sibsp with parch are heavily correlated
"""
# Out:
# '\nsibsp with parch are heavily correlated\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
titanic.groupby("Pclass")["Age"].describe()
# Out:
#         count       mean        std   min        25%        50%      75%   max
# Pclass
# 1       323.0  39.555048  13.863639  0.92  30.000000  40.000000  49.0000  80.0
# 2       277.0  29.977433  13.563141  0.67  22.948773  29.000000  36.5000  70.0
# 3       709.0  25.432757  10.605975  0.17  20.000000  25.315435  31.4561  74.0

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
graph = sns.FacetGrid(titanic, col ='Gender')
graph.map(plt.hist, 'Age')
