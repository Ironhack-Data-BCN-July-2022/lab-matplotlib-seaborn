# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# Your Code Here

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('../data/Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'

# %%
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,4.)})
sns.set_style("whitegrid")

# %%
# AVERAGE STEPS BY MONTH_ENCODED

fitbit_1 = pd.DataFrame(fitbit.groupby('Months_encoded')['Steps'].median()).reset_index()

# %%
plt.plot(fitbit_1['Months_encoded'], fitbit_1['Steps']);

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
fitbit_2 = pd.DataFrame(fitbit.groupby('Work_or_Weekend')['Steps'].median()).reset_index()
fitbit_2
# Out:
#    Work_or_Weekend    Steps
# 0                0   9998.0
# 1                1  10445.5

# %%
plt.pie(fitbit_2['Steps'], labels=['Weekend','Workday'], autopct='%.1f%%')
plt.legend()
#plt.annotate(text=[fitbit_2['Steps'][0], fitbit_2['Steps'][1]])
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
activity=['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']
for i in activity:
    plt.figure()
    plt.scatter(fitbit[i], fitbit['Steps'])
plt.show()

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('../data/titanic.csv')
titanic.sample(5)
# Out:
#       PassengerId  Survived  Pclass  \
# 80             81       0.0       3
# 148           149       0.0       2
# 934           935       NaN       2
# 1206         1207       NaN       3
# 1056         1057       NaN       3
#
#                                             Name  Gender   Age  SibSp  Parch  \
# 80                          Waelens, Mr. Achille    male  22.0      0      0
# 148     Navratil, Mr. Michel ("Louis M Hoffman")    male  36.5      0      2
# 934        Corbett, Mrs. Walter H (Irene Colvin)  female  30.0      0      0
# 1206                        Hagardon, Miss. Kate  female  17.0      0      0
# 1056  Kink-Heilmann, Mrs. Anton (Luise Heilmann)  female  26.0      1      1
#
#            Ticket     Fare Cabin Embarked
# 80         345767   9.0000    U0        S
# 148        230080  26.0000    F2        S
# 934        237249  13.0000    U0        S
# 1206  AQ/3. 30631   7.7333    U0        Q
# 1056       315153  22.0250    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include=['int64','float64'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include=['object'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("classic")

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic.Age.plot.hist(bins=30, color="#fd7e14",rwidth=0.9);

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
titanic.Age.plot.hist(bins=10, color="#fd7e14",rwidth=0.9)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic.Age.plot.hist(bins=20, color="#fd7e14",rwidth=0.9)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic.Age.plot.hist(bins=50, color="#fd7e14",rwidth=0.9)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The number of bins means the number of bars present in the histogram. These bars group the data, 
therefore, the more bins, the more we can accurately visualize the variation in the data
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

# %%
titanic["Gender"].value_counts()
# Out:
# male      843
# female    466
# Name: Gender, dtype: int64

# %%
titanic["Gender"].value_counts().plot(kind="bar", color="green", figsize=(12,6), title="Passengers by gender")
plt.xticks(rotation=0);

# %%
# Method 2 - seaborn
sns.histplot(x=titanic.Gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
titanic["Pclass"].value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
sns.countplot(x=titanic.Pclass)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(x="Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
"""
A boxplot serves to easily visualize the statistics of the feature `Age`. We can se the minum and maximum values,
the median and the values within the IQR as well as other metrics
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
We can observe various outliers on the right end, over 60, and the majority of the sample ranges from 22/23 to 36/37. 
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.histplot(x="Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
It allows to see the which groups of ages are the most numerous and better visualize where the bulk of the data
is located.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(x=titanic.Age, y=titanic.Fare)

# %%
# Method 2 - seaborn

# %%
sns.scatterplot(x="Age", y="Fare", data=titanic);

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr = titanic.corr()
corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %%
mask = np.triu(np.ones_like(corr, dtype=bool)) 
color_map = sns.diverging_palette(0, 10, as_cmap=True)
sns.heatmap(corr,  
            mask = mask,
            cmap=color_map,
            square=True, 
            linewidth=0.5, 
            vmax=1,
            cbar_kws={"shrink": .5}
);

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The most correlated features are 'Pclass' and 'Fare'
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.catplot(data=titanic, x="Pclass", y="Age", jitter=True)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.catplot(data=titanic, x="Gender", y="Age", jitter=True)
